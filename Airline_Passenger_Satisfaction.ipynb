# %% [markdown]
# <a href="https://colab.research.google.com/github/rofiat13/projects/blob/main/Airline_Passenger_Satisfaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pass_sat= pd.read_csv("https://s3.us-west-1.wasabisys.com/dphi/datasets/230/train_dataset.csv?AWSAccessKeyId=ABSZWDH67WW3G8YX40WD&Signature=a12vpKYzlE03qAqkddjNGY0KLM8%3D&Expires=1654350818")

# %%
pass_sat.head()
# Out:
#    Age  Flight Distance  Inflight wifi service  \
# 0   35              971                      3
# 1   32             1092                      0
# 2   46             2915                      0
# 3   56             2556                      4
# 4   54              468                      1
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       5              4
# 1                                  0                       0              3
# 2                                  5                       0              5
# 3                                  4                       4              4
# 4                                  4                       1              4
#
#    Food and drink  Online boarding  Seat comfort  Inflight entertainment  ...  \
# 0               2                3             3                       2  ...
# ...

# %%
pass_sat.shape
# Out:
# (50761, 26)

# %%
pass_sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50761 entries, 0 to 50760
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                50761 non-null  int64
#  1   Flight Distance                    50761 non-null  int64
#  2   Inflight wifi service              50761 non-null  int64
#  3   Departure/Arrival time convenient  50761 non-null  int64
#  4   Ease of Online booking             50761 non-null  int64
#  5   Gate location                      50761 non-null  int64
#  6   Food and drink                     50761 non-null  int64
#  7   Online boarding                    50761 non-null  int64
#  8   Seat comfort                       50761 non-null  int64
#  9   Inflight entertainment             50761 non-null  int64
#  10  On-board service                   50761 non-null  int64
# ...

# %%
pass_sat.describe()
# Out:
#                 Age  Flight Distance  Inflight wifi service  \
# count  50761.000000     50761.000000           50761.000000
# mean      39.428518      1192.632730               2.737456
# std       15.127063       999.983962               1.329768
# min        7.000000        31.000000               0.000000
# 25%       27.000000       413.000000               2.000000
# 50%       40.000000       846.000000               3.000000
# 75%       51.000000      1744.000000               4.000000
# max       85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                       50761.000000            50761.000000
# mean                            3.058490                2.762455
# std                             1.525301                1.400141
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# ...

# %%
pass_sat['satisfaction'].value_counts()
# Out:
# neutral or dissatisfied    28764
# satisfied                  21997
# Name: satisfaction, dtype: int64

# %%
from seaborn.utils import iqr
Q1= pass_sat.quantile(0.25)
Q3= pass_sat.quantile(0.75)
IQR= Q3-Q1
print(IQR)
# Out:
# Age                                    24.0
# Flight Distance                      1331.0
# Inflight wifi service                   2.0
# Departure/Arrival time convenient       2.0
# Ease of Online booking                  2.0
# Gate location                           2.0
# Food and drink                          2.0
# Online boarding                         2.0
# Seat comfort                            3.0
# Inflight entertainment                  2.0
# On-board service                        2.0
# Leg room service                        2.0
# Baggage handling                        2.0
# Checkin service                         1.0
# Inflight service                        2.0
# Cleanliness                             2.0
# Departure Delay in Minutes             12.0
# Arrival Delay in Minutes               13.0
# Gender_Female                           1.0
# Gender_Male                             1.0
# Type of Travel_Business travel          1.0
# ...

# %%
print(pass_sat<(Q1-1.5*IQR)) or (pass_sat>Q3+1.5*IQR)
# Out:
#          Age  Arrival Delay in Minutes  Baggage handling  Checkin service  \
# 0      False                     False             False            False
# 1      False                     False             False             True
# 2      False                     False             False            False
# 3      False                     False             False            False
# 4      False                     False             False            False
# ...      ...                       ...               ...              ...
# 50756  False                     False             False            False
# 50757  False                     False             False            False
# 50758  False                     False             False            False
# 50759  False                     False             False            False
# 50760  False                     False             False            False
#
#        Class_Business  Class_Eco  Class_Eco Plus  Cleanliness  \
# ...

# %%
print(pass_sat['Flight Distance'].quantile(0.5))
print(pass_sat['Flight Distance'].quantile(0.95))
print(pass_sat['Flight Distance'].quantile(0.75))
# Out:
# 846.0
# 3392.0
# 1744.0

# %%
pass_sat['Flight Distance']=np.where(pass_sat['Flight Distance']>3392.0,1744.0,pass_sat['Flight Distance'])
pass_sat['Flight Distance'].describe()
# Out:
# count    50761.000000
# mean      1094.429247
# std        828.522274
# min         31.000000
# 25%        413.000000
# 50%        846.000000
# 75%       1744.000000
# max       3392.000000
# Name: Flight Distance, dtype: float64

# %%
print(pass_sat['Departure Delay in Minutes'].quantile(0.5))
print(pass_sat['Departure Delay in Minutes'].quantile(0.95))
print(pass_sat['Departure Delay in Minutes'].quantile(0.75))
# Out:
# 0.0
# 76.0
# 12.0

# %%
pass_sat['Departure Delay in Minutes']=np.where(pass_sat['Departure Delay in Minutes']>76.0,12.0,pass_sat['Departure Delay in Minutes'])
pass_sat['Departure Delay in Minutes'].describe()
# Out:
# count    50761.000000
# mean         8.090857
# std         14.783153
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         12.000000
# max         76.000000
# Name: Departure Delay in Minutes, dtype: float64

# %%
print(pass_sat['Arrival Delay in Minutes'].quantile(0.5))
print(pass_sat['Arrival Delay in Minutes'].quantile(0.95))
print(pass_sat['Arrival Delay in Minutes'].quantile(0.75))
# Out:
# 0.0
# 79.0
# 13.0

# %%
pass_sat['Arrival Delay in Minutes']=np.where(pass_sat['Arrival Delay in Minutes']>79.0,13.0,pass_sat['Arrival Delay in Minutes'])
pass_sat['Arrival Delay in Minutes'].describe()
# Out:
# count    50761.000000
# mean         8.457556
# std         15.147679
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         13.000000
# max         79.000000
# Name: Arrival Delay in Minutes, dtype: float64

# %%
y=pass_sat['satisfaction']
x=pass_sat.drop(['satisfaction'],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)

# %%
x.head()
# Out:
#    Age  Flight Distance  Inflight wifi service  \
# 0   35            971.0                      3
# 1   32           1092.0                      0
# 2   46           2915.0                      0
# 3   56           2556.0                      4
# 4   54            468.0                      1
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       5              4
# 1                                  0                       0              3
# 2                                  5                       0              5
# 3                                  4                       4              4
# 4                                  4                       1              4
#
#    Food and drink  Online boarding  Seat comfort  Inflight entertainment  ...  \
# 0               2                3             3                       2  ...
# ...

# %%
print(y)
# Out:
# [0 1 1 ... 1 0 0]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=0)

# %%
print(y_train.shape)
print(y_test.shape)
print(x_test.shape)
print(x_train.shape)
# Out:
# (35532,)
# (15229,)
# (15229, 25)
# (35532, 25)

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x_train= sc.fit_transform(x_train)
x_test= sc.transform(x_test)

# %%
from sklearn.decomposition import PCA
pca= PCA()
pca.fit(x_train)
# Out:
# PCA()

# %%
pca.n_components_
# Out:
# 25

# %%
pca.transform(x_train)
pca.transform(x_test)
# Out:
# array([[-1.14019769e+00,  2.14650233e+00,  1.95413451e+00, ...,
#         -3.69369099e-16,  2.69031743e-16,  5.93263551e-18],
#        [-3.60020632e-01,  1.23752137e+00, -4.02964785e+00, ...,
#         -7.02436006e-16,  4.69871378e-17, -4.95785157e-17],
#        [ 1.40298960e+00, -2.79131802e+00,  8.27033196e-01, ...,
#         -1.89549565e-17,  3.24542894e-16,  6.02511644e-17],
#        ...,
#        [-2.47618791e-01,  2.52541895e+00, -2.03097996e-01, ...,
#         -3.69369099e-16, -2.86079770e-16, -4.95785157e-17],
#        [-2.55254807e+00, -2.54416158e-01, -2.24292436e+00, ...,
#          1.01147079e-15, -2.86079770e-16, -4.95785157e-17],
#        [-2.97271716e-01,  1.56436652e+00,  4.16283202e-02, ...,
#         -4.92661467e-16, -4.02455846e-16, -1.24900090e-16]])

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression(random_state=1)
clf=clf.fit(x_train, y_train)

# %%
pred=clf.predict(x_test)

# %%
pred
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
clf.score(x_test,y_test)
# Out:
# 0.8625648433908989

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.8625648433908989

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test, pred)
cm
# Out:
# array([[7657,  946],
#        [1147, 5479]])

# %%
from sklearn.tree import DecisionTreeClassifier
clf1=DecisionTreeClassifier()
clf1= clf1.fit(x_train,y_train)

# %%
prediction=clf1.predict(x_test)

# %%
clf1.score(x_test,y_test)
# Out:
# 0.9289513428327533

# %%
from sklearn.metrics import confusion_matrix
cm1= confusion_matrix(y_test, prediction)
cm1
# Out:
# array([[8061,  542],
#        [ 540, 6086]])

# %%
from sklearn import tree

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      8603
#            1       0.92      0.92      0.92      6626
#
#     accuracy                           0.93     15229
#    macro avg       0.93      0.93      0.93     15229
# weighted avg       0.93      0.93      0.93     15229
